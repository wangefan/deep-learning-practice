# %% [markdown]
# # enumerate
# 回傳container裡的元素再加上index

# %%
ls = ['I', 'love', 'you', 'forever']
newLs = list(enumerate(ls))
print(newLs)
# Out:
# [(0, 'I'), (1, 'love'), (2, 'you'), (3, 'forever')]
